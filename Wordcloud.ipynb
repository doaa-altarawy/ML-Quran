# %% [markdown]
# ### Wordcloud Quran and Hadith

# %%
import pandas as pd
import oj_scripts as oj
import importlib
import numpy as np
import matplotlib.pyplot as plt

# %%
importlib.reload(oj)
# Out:
# <module 'oj_scripts' from 'C:\\Users\\doaa\\Documents\\Git\\ML-Quran\\oj_scripts.py'>

# %%
Quran_df = oj.Quran()

clean = oj.cleaner(Quran_df['Verse Text'])
Quran_df["Clean Text"] = clean
Quran_df.head()
# Out:
#   Surah Name  Surah Number  Verse Number  \
# 0    الفاتحة             1             1
# 1    الفاتحة             1             2
# 2    الفاتحة             1             3
# 3    الفاتحة             1             4
# 4    الفاتحة             1             5
#
#                                  Verse Text              Clean Text
# 0     بِسْمِ اللَّهِ الرَّحْمَنِ الرَّحِيمِ  بسم الله الرحمن الرحيم
# 1     الْحَمْدُ لِلَّهِ رَبِّ الْعَالَمِينَ   الحمد لله رب العالمين
# 2                    الرَّحْمَنِ الرَّحِيمِ           الرحمن الرحيم
# 3                   مَالِكِ يَوْمِ الدِّينِ          مالك يوم الدين
# 4  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ  اياك نعبد واياك نستعين

# %%
df = Quran_df
df.shape
# Out:
# (6236, 5)

# %%
df.columns = ['sura_name', 'sura', 'aya' , 'text', 'clean_text']
df.head()
# Out:
#   sura_name  sura  aya                                      text  \
# 0   الفاتحة     1    1     بِسْمِ اللَّهِ الرَّحْمَنِ الرَّحِيمِ
# 1   الفاتحة     1    2     الْحَمْدُ لِلَّهِ رَبِّ الْعَالَمِينَ
# 2   الفاتحة     1    3                    الرَّحْمَنِ الرَّحِيمِ
# 3   الفاتحة     1    4                   مَالِكِ يَوْمِ الدِّينِ
# 4   الفاتحة     1    5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
#
#                clean_text
# 0  بسم الله الرحمن الرحيم
# 1   الحمد لله رب العالمين
# 2           الرحمن الرحيم
# 3          مالك يوم الدين
# 4  اياك نعبد واياك نستعين

# %%
df['words'] =
# Out:
#      sura_name  sura  aya                                      text  \
# 0      الفاتحة     1    1     بِسْمِ اللَّهِ الرَّحْمَنِ الرَّحِيمِ
# 1      الفاتحة     1    2     الْحَمْدُ لِلَّهِ رَبِّ الْعَالَمِينَ
# 2      الفاتحة     1    3                    الرَّحْمَنِ الرَّحِيمِ
# 3      الفاتحة     1    4                   مَالِكِ يَوْمِ الدِّينِ
# 4      الفاتحة     1    5  إِيَّاكَ نَعْبُدُ وَإِيَّاكَ نَسْتَعِينُ
# ...        ...   ...  ...                                       ...
# 6231     الناس   114    2                           مَلِكِ النَّاسِ
# 6232     الناس   114    3                           إِلَهِ النَّاسِ
# 6233     الناس   114    4       مِنْ شَرِّ الْوَسْوَاسِ الْخَنَّاسِ
# 6234     الناس   114    5   الَّذِي يُوَسْوِسُ فِي صُدُورِ النَّاسِ
# 6235     الناس   114    6                مِنَ الْجِنَّةِ وَالنَّاسِ
#
#                     clean_text
# 0       بسم الله الرحمن الرحيم
# 1        الحمد لله رب العالمين
# 2                الرحمن الرحيم
# 3               مالك يوم الدين
# 4       اياك نعبد واياك نستعين
# ...                        ...
# 6231                 ملك الناس
# 6232                 اله الناس
# 6233      من شر الوسواس الخناس
# 6234  الذي يوسوس في صدور الناس
# 6235           من الجنه والناس
#
# [6236 rows x 5 columns]

# %% [markdown]
# ## Wordcloud

# %%
from wordcloud import WordCloud

# %%
trans_df = oj.Translation()
trans_df
# Out:
#      Surah Name  Surah Number  Verse Number  \
# 0       الفاتحة             1             1
# 1       الفاتحة             1             2
# 2       الفاتحة             1             3
# 3       الفاتحة             1             4
# 4       الفاتحة             1             5
# ...         ...           ...           ...
# 6231      الناس           114             2
# 6232      الناس           114             3
# 6233      الناس           114             4
# 6234      الناس           114             5
# 6235      الناس           114             6
#
#                                              Verse Text
# 0     In the name of Allah, the Entirely Merciful, t...
# 1     [All] praise is [due] to Allah, Lord of the wo...
# 2       The Entirely Merciful, the Especially Merciful,
# 3                   Sovereign of the Day of Recompense.
# 4         It is You we worship and You we ask for help.
# ...                                                 ...
# 6231                          The Sovereign of mankind.
# 6232                                The God of mankind,
# 6233        From the evil of the retreating whisperer -
# 6234  Who whispers [evil] into the breasts of mankind -
# 6235                  From among the jinn and mankind."
#
# [6236 rows x 4 columns]

# %%
import string

# %%
# joined_quran = trans_df['Verse Text'].str.cat(sep=' ')

joined_quran = df['clean_text'].str.cat(sep=' ')
joined_quran[:97]
# Out:
# 'بسم الله الرحمن الرحيم الحمد لله رب العالمين الرحمن الرحيم مالك يوم الدين اياك نعبد واياك نستعين '

# %%
cleaned = joined_quran.translate(str.maketrans('', '', string.punctuation))
cleaned[:97]
# Out:
# 'بسم الله الرحمن الرحيم الحمد لله رب العالمين الرحمن الرحيم مالك يوم الدين اياك نعبد واياك نستعين '

# %%
wordcloud = WordCloud(background_color="white", 
                      max_words=100,
                      contour_width=3, 
                      contour_color='steelblue',
                      width = 600, height = 600)

# %%
wordcloud.generate(cleaned)

# %%
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=600x600>

# %%
# from spacy.lang.en import English
from spacy.lang.ar import Arabic

# from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.ar.stop_words import STOP_WORDS

# %%
# STOP_WORDS

# %%
# nlp = English()
nlp = Arabic()

# %%
my_doc = nlp(cleaned)

# Create list of word tokens
token_list = []
for token in my_doc:
    token_list.append(token.text)


# Create list of word tokens after removing stopwords
filtered_sentence =[] 

for word in token_list:
    lexeme = nlp.vocab[word]
    if lexeme.is_stop == False:
        filtered_sentence.append(word) 
print(token_list[:10])
print(filtered_sentence[:10])
# Out:
# ['بسم', 'الله', 'الرحمن', 'الرحيم', 'الحمد', 'لله', 'رب', 'العالمين', 'الرحمن', 'الرحيم']
# ['بسم', 'الله', 'الرحمن', 'الرحيم', 'الحمد', 'لله', 'رب', 'العالمين', 'الرحمن', 'الرحيم']

# %%
len(token_list), len(filtered_sentence)
# Out:
# (77797, 53896)

# %%
filtered_ = " ".join(filtered_sentence)

# %%
wordcloud = WordCloud(background_color="white", 
                      max_words=50,
                      contour_width=3, 
                      contour_color='steelblue',
                      width = 600, height = 600)

wordcloud.generate(filtered_)
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FA3B1AB30D0>

# %% [markdown]
# ## LDA

# %%
import gensim
from gensim.utils import simple_preprocess
import nltk
from nltk.corpus import stopwords

# stop_words = stopwords.words('english')
# stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
nltk.download("stopwords")
stop_words = stopwords.words('arabic')

def sent_to_words(sentences):
    """
    Will convert sentances to words
    """
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))
        
        
def remove_stopwords(texts):
    """
    Will remove stopwords
    """
    return [[word for word in simple_preprocess(str(doc)) 
             if word not in stop_words] for doc in texts]

# data = trans_df['Verse Text'].values.tolist()
data = df['clean_text'].values.tolist()

data_words = list(sent_to_words(data))

print(data_words[:10])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\doaa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [['بسم', 'الله', 'الرحمن', 'الرحيم'], ['الحمد', 'لله', 'رب', 'العالمين'], ['الرحمن', 'الرحيم'], ['مالك', 'يوم', 'الدين'], ['اياك', 'نعبد', 'واياك', 'نستعين'], ['اهدنا', 'الصراط', 'المستقيم'], ['صراط', 'الذين', 'انعمت', 'عليهم', 'غير', 'المغضوب', 'عليهم', 'ولا', 'الضالين'], ['الم'], ['ذلك', 'الكتاب', 'لا', 'ريب', 'فيه', 'هدي', 'للمتقين'], ['الذين', 'يءمنون', 'بالغيب', 'ويقيمون', 'الصلاه', 'ومما', 'رزقناهم', 'ينفقون']]

# %%
# remove stop words
data_words = remove_stopwords(data_words)
print(data_words[:10])
# Out:
# [['بسم', 'الله', 'الرحمن', 'الرحيم'], ['الحمد', 'لله', 'رب', 'العالمين'], ['الرحمن', 'الرحيم'], ['مالك', 'يوم', 'الدين'], ['اياك', 'نعبد', 'واياك', 'نستعين'], ['اهدنا', 'الصراط', 'المستقيم'], ['صراط', 'انعمت', 'عليهم', 'المغضوب', 'عليهم', 'الضالين'], ['الم'], ['الكتاب', 'ريب', 'هدي', 'للمتقين'], ['يءمنون', 'بالغيب', 'ويقيمون', 'الصلاه', 'ومما', 'رزقناهم', 'ينفقون']]

# %%
import gensim.corpora as corpora

# Create Dictionary
id2word = corpora.Dictionary(data_words)

# Create Corpus
texts = data_words

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %%
from pprint import pprint

# number of topics
num_topics = 5

# Build LDA model
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=num_topics,
                                       passes=100)

# Print the Keyword in the 10 topics
pprint(lda_model.print_topics(), width = 100) #pprint allows for things to be printed in a easier to read manner (with tabs).
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.016*"ان" + 0.007*"علي" + 0.005*"قالوا" + 0.005*"وهم" + 0.005*"اولءك" + 0.004*"منهم" + '
#   '0.004*"قال" + 0.004*"عليهم" + 0.004*"امنوا" + 0.004*"العذاب"'),
#  (1,
#   '0.043*"الله" + 0.029*"ان" + 0.026*"الا" + 0.011*"علي" + 0.007*"السماوات" + 0.007*"الارض" + '
#   '0.006*"وان" + 0.005*"والارض" + 0.004*"انه" + 0.004*"قل"'),
#  (2,
#   '0.017*"ان" + 0.017*"الله" + 0.009*"امنوا" + 0.008*"الي" + 0.007*"علي" + 0.007*"الا" + '
#   '0.006*"او" + 0.005*"جنات" + 0.005*"الصالحات" + 0.005*"كنتم"'),
#  (3,
#   '0.029*"الله" + 0.018*"ان" + 0.014*"قال" + 0.009*"انا" + 0.009*"الي" + 0.008*"علي" + 0.007*"الا" '
#   '+ 0.007*"اني" + 0.006*"قل" + 0.006*"قالوا"'),
#  (4,
#   '0.041*"الله" + 0.026*"ان" + 0.011*"علي" + 0.007*"يوم" + 0.007*"وان" + 0.006*"الي" + 0.006*"او" '
#   '+ 0.005*"قل" + 0.004*"والارض" + 0.004*"فان"')]
